# %% [markdown]
# #Distribution

# %% [markdown]
# #  1.Simulate 30 rolls with =RANDBETWEEN(1,6). What is the probability of rolling a 3 exactly 5 times? (Hint: Use BINOM.DIST) .
#   - number of rolls (trails),n=30
#   - probability of success (rolling a3),P=1/6
#   - Number of successes required,x=5
#   formula     BINOM.DIST
#   - 5->exact number of successes
#   - 30->number of trails
#   - 1/6-> problity of success
#   - FALSE-> exact probability  (not cumulative)
#   - p(X=5)=0.18
#   he probability of rolling a 3 exactly 5 times in 30 rolls is approximatly:
#   18%.
# # 3.A dataset has a mean of 50 and a standard deviation of 5. What percentage of values lie between 45 and 55 if the data follows a normal distribution?
#    ->data follows a normaol distribution , wew use the rule (68-95-99.7 rule).
#    -  Mean (U)=50
#    - standard deviation (a)=5
#    - Range given: 45 to 55
#    - 45=u-1a
#    - 55=u+1a
#    approximately 68% value lie between 45 and 55.
#    -   ANSWER 68%  .
# # 4.What is the concept of standardization (z-score), and why is it important in data analysis? Explain the  formula and how standardization transforms a dataset.
#  - Concept of Standardization (Z-Score)
#   Standardization, also called z-score normalization, is a statistical methd used convert data values into a common scale base on how far they are from the mesan , measured in terms of standard deviation.
#   - Z-score formula
#     z= x-u/a
#     how standardization transforms a Dataset
#     - the new mean becoms 0
#     - the new standard deviation become 1
#     - original units are removed
#     - values are expresed relative to he mean
#     EXAMPLE
#     if the mean = 50 and standard deviation =5:
#     - a value of 55->z=(55-50)/5=1.
#     ->1 standard deviation above the mean.
#     - a value of 45->z =(45-50)/5= -1
#     ->1 satandard dedviaion below the mean.
# # 5. What is Kurtosis and their type?
# -  KURTOSIS
# KURTOSIS is statical measure that descries the shape of a distribution, specifically the degree of peakedness and the heaviness of the tails compared to a normal distribution. it helps us understand how extreme values (outlirs )are  distributed in data .
#   here are  THREE main typ of Kurtosis :
#   1-Mesokurtic
#   2- leptokurtic
#   3- playkurtic
# # 6.Explain why the uniform distribution is a good model for the outcome of rolling a fair die.

# %% [markdown]
# #
